# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import RidgeCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import LabelEncoder # Import LabelEncoder

# %%
# Load your dataset
df = pd.read_csv('/content/drive/MyDrive/finaldata.csv')

# %%
# Step 2: Label encode the required columns

label_cols = ['data', 'route_type', 'is_cutoff']

# Apply label encoding
le = LabelEncoder()
for col in label_cols:
    df[col] = le.fit_transform(df[col])

# %%
le_source = LabelEncoder()
le_dest = LabelEncoder()

df['source_center'] = le_source.fit_transform(df['source_center'])
df['destination_center'] = le_dest.fit_transform(df['destination_center'])

# Optional: see the mappings
print(dict(zip(le_source.classes_, le_source.transform(le_source.classes_))))
print(dict(zip(le_dest.classes_, le_dest.transform(le_dest.classes_))))
# Out:
# {'IND000000AAL': np.int64(0), 'IND000000AAQ': np.int64(1), 'IND000000AAS': np.int64(2), 'IND000000AAZ': np.int64(3), 'IND000000ABA': np.int64(4), 'IND000000ABD': np.int64(5), 'IND000000ABG': np.int64(6), 'IND000000ACA': np.int64(7), 'IND000000ACB': np.int64(8), 'IND000000ACK': np.int64(9), 'IND000000ACN': np.int64(10), 'IND000000ACT': np.int64(11), 'IND000000ADM': np.int64(12), 'IND000000ADV': np.int64(13), 'IND000000AEL': np.int64(14), 'IND000000AEM': np.int64(15), 'IND000000AET': np.int64(16), 'IND000000AFF': np.int64(17), 'IND000000AFG': np.int64(18), 'IND000000AFJ': np.int64(19), 'IND000000AFR': np.int64(20), 'IND000000AFT': np.int64(21), 'IND110014AAA': np.int64(22), 'IND110020AAB': np.int64(23), 'IND110024AAA': np.int64(24), 'IND110030AAD': np.int64(25), 'IND110035AAC': np.int64(26), 'IND110037AAK': np.int64(27), 'IND110037AAM': np.int64(28), 'IND110039AAA': np.int64(29), 'IND110043AAA': np.int64(30), 'IND110043AAC': np.int64(31), 'IND110044AAB': np.int64(32), 'IND110052AAA': np.int64(33), 'IND110064AAA': np.int64(34), 'IND110077AAA': np.int64(35), 'IND110078AAA': np.int64(36), 'IND110083AAA': np.int64(37), 'IND110085AAB': np.int64(38), 'IND110092AAC': np.int64(39), 'IND110093AAA': np.int64(40), 'IND110095AAB': np.int64(41), 'IND121001AAA': np.int64(42), 'IND121002AAA': np.int64(43), 'IND121002AAB': np.int64(44), 'IND121004AAA': np.int64(45), 'IND121004AAB': np.int64(46), 'IND121004AAC': np.int64(47), 'IND121102AAA': np.int64(48), 'IND122001AAA': np.int64(49), 'IND122001AAD': np.int64(50), 'IND122001AAJ': np.int64(51), 'IND122002AAD': np.int64(52), 'IND122004AAA': np.int64(53), 'IND122503AAA': np.int64(54), 'IND123001AAA': np.int64(55), 'IND123401AAB': np.int64(56), 'IND124001AAB': np.int64(57), 'IND124103AAA': np.int64(58), 'IND124112AAA': np.int64(59), 'IND124141AAA': np.int64(60), 'IND124507AAA': np.int64(61), 'IND125001AAA': np.int64(62), 'IND125005AAA': np.int64(63), 'IND125033AAA': np.int64(64), 'IND125047AAB': np.int64(65), 'IND125050AAA': np.int64(66), 'IND125051AAA': np.int64(67), 'IND125104AAA': np.int64(68), 'IND125111AAA': np.int64(69), 'IND125121AAA': np.int64(70), 'IND126102AAA': np.int64(71), 'IND126112AAA': np.int64(72), 'IND127021AAA': np.int64(73), 'IND127201AAA': np.int64(74), 'IND131021AAA': np.int64(75), 'IND131028AAB': np.int64(76), 'IND131028AAE': np.int64(77), 'IND131301AAA': np.int64(78), 'IND132001AAA': np.int64(79), 'IND132103AAA': np.int64(80), 'IND132103AAB': np.int64(81), 'IND133004AAA': np.int64(82), 'IND134102AAA': np.int64(83), 'IND134109AAA': np.int64(84), 'IND134203AAA': np.int64(85), 'IND135001AAA': np.int64(86), 'IND136027AAA': np.int64(87), 'IND136118AAA': np.int64(88), 'IND136128AAA': np.int64(89), 'IND140001AAA': np.int64(90), 'IND140118AAA': np.int64(91), 'IND140301AAA': np.int64(92), 'IND140401AAA': np.int64(93), 'IND140406AAA': np.int64(94), 'IND140501AAA': np.int64(95), 'IND140901AAA': np.int64(96), 'IND141003AAB': np.int64(97), 'IND141010AAA': np.int64(98), 'IND141109AAA': np.int64(99), 'IND141115AAA': np.int64(100), 'IND142001AAB': np.int64(101), 'IND142026AAA': np.int64(102), 'IND142401AAA': np.int64(103), 'IND143001AAA': np.int64(104), 'IND144001AAA': np.int64(105), 'IND144001AAB': np.int64(106), 'IND144001AAC': np.int64(107), 'IND144040AAA': np.int64(108), 'IND144401AAB': np.int64(109), 'IND144514AAA': np.int64(110), 'IND144527AAA': np.int64(111), 'IND144601AAA': np.int64(112), 'IND145001AAA': np.int64(113), 'IND147001AAB': np.int64(114), 'IND147001AAD': np.int64(115), 'IND147101AAA': np.int64(116), 'IND147105AAA': np.int64(117), 'IND147201AAA': np.int64(118), 'IND147301AAA': np.int64(119), 'IND148023AAA': np.int64(120), 'IND148028AAA': np.int64(121), 'IND148101AAA': np.int64(122), 'IND148102AAA': np.int64(123), 'IND151001AAA': np.int64(124), 'IND151103AAA': np.int64(125), 'IND151302AAA': np.int64(126), 'IND151505AAA': np.int64(127), 'IND151506AAA': np.int64(128), 'IND152024AAA': np.int64(129), 'IND152026AAA': np.int64(130), 'IND152101AAA': np.int64(131), 'IND152107AAA': n ...
# {'IND000000AAL': np.int64(0), 'IND000000AAS': np.int64(1), 'IND000000AAZ': np.int64(2), 'IND000000ABA': np.int64(3), 'IND000000ABD': np.int64(4), 'IND000000ACA': np.int64(5), 'IND000000ACB': np.int64(6), 'IND000000ACN': np.int64(7), 'IND000000ACO': np.int64(8), 'IND000000ACS': np.int64(9), 'IND000000ADM': np.int64(10), 'IND000000AEL': np.int64(11), 'IND000000AET': np.int64(12), 'IND000000AFF': np.int64(13), 'IND000000AFJ': np.int64(14), 'IND000000AFS': np.int64(15), 'IND000000AFT': np.int64(16), 'IND110005AAA': np.int64(17), 'IND110014AAA': np.int64(18), 'IND110020AAB': np.int64(19), 'IND110024AAA': np.int64(20), 'IND110030AAD': np.int64(21), 'IND110035AAC': np.int64(22), 'IND110037AAB': np.int64(23), 'IND110037AAK': np.int64(24), 'IND110037AAM': np.int64(25), 'IND110039AAA': np.int64(26), 'IND110043AAA': np.int64(27), 'IND110043AAC': np.int64(28), 'IND110044AAB': np.int64(29), 'IND110046AAA': np.int64(30), 'IND110052AAA': np.int64(31), 'IND110064AAA': np.int64(32), 'IND110064AAB': np.int64(33), 'IND110078AAA': np.int64(34), 'IND110083AAA': np.int64(35), 'IND110085AAA': np.int64(36), 'IND110085AAB': np.int64(37), 'IND110087AAA': np.int64(38), 'IND110092AAC': np.int64(39), 'IND110093AAA': np.int64(40), 'IND110095AAB': np.int64(41), 'IND121001AAA': np.int64(42), 'IND121002AAA': np.int64(43), 'IND121002AAB': np.int64(44), 'IND121004AAA': np.int64(45), 'IND121004AAB': np.int64(46), 'IND121004AAC': np.int64(47), 'IND121102AAA': np.int64(48), 'IND122001AAA': np.int64(49), 'IND122001AAD': np.int64(50), 'IND122001AAJ': np.int64(51), 'IND122050AAA': np.int64(52), 'IND122101AAC': np.int64(53), 'IND122413AAE': np.int64(54), 'IND122503AAA': np.int64(55), 'IND123001AAA': np.int64(56), 'IND123106AAB': np.int64(57), 'IND123401AAB': np.int64(58), 'IND124001AAB': np.int64(59), 'IND124103AAA': np.int64(60), 'IND124112AAA': np.int64(61), 'IND124141AAA': np.int64(62), 'IND124507AAA': np.int64(63), 'IND125001AAA': np.int64(64), 'IND125005AAA': np.int64(65), 'IND125033AAA': np.int64(66), 'IND125047AAB': np.int64(67), 'IND125050AAA': np.int64(68), 'IND125051AAA': np.int64(69), 'IND125104AAA': np.int64(70), 'IND125111AAA': np.int64(71), 'IND125121AAA': np.int64(72), 'IND126102AAA': np.int64(73), 'IND127021AAA': np.int64(74), 'IND127201AAA': np.int64(75), 'IND131028AAA': np.int64(76), 'IND131028AAB': np.int64(77), 'IND131028AAE': np.int64(78), 'IND131301AAA': np.int64(79), 'IND132001AAA': np.int64(80), 'IND132039AAA': np.int64(81), 'IND132103AAA': np.int64(82), 'IND132103AAB': np.int64(83), 'IND134102AAA': np.int64(84), 'IND134203AAA': np.int64(85), 'IND135001AAA': np.int64(86), 'IND136027AAA': np.int64(87), 'IND136118AAA': np.int64(88), 'IND136128AAA': np.int64(89), 'IND140001AAA': np.int64(90), 'IND140118AAA': np.int64(91), 'IND140301AAA': np.int64(92), 'IND140401AAA': np.int64(93), 'IND140406AAA': np.int64(94), 'IND140501AAA': np.int64(95), 'IND140603AAA': np.int64(96), 'IND140901AAA': np.int64(97), 'IND141109AAA': np.int64(98), 'IND141115AAA': np.int64(99), 'IND142001AAB': np.int64(100), 'IND142026AAA': np.int64(101), 'IND142401AAA': np.int64(102), 'IND143001AAA': np.int64(103), 'IND144001AAA': np.int64(104), 'IND144001AAB': np.int64(105), 'IND144040AAA': np.int64(106), 'IND144401AAB': np.int64(107), 'IND144514AAA': np.int64(108), 'IND144601AAA': np.int64(109), 'IND145001AAA': np.int64(110), 'IND147001AAB': np.int64(111), 'IND147001AAD': np.int64(112), 'IND147101AAA': np.int64(113), 'IND147105AAA': np.int64(114), 'IND147201AAA': np.int64(115), 'IND147301AAA': np.int64(116), 'IND148001AAA': np.int64(117), 'IND148023AAA': np.int64(118), 'IND148024AAB': np.int64(119), 'IND148101AAA': np.int64(120), 'IND148102AAA': np.int64(121), 'IND151001AAA': np.int64(122), 'IND151103AAA': np.int64(123), 'IND151302AAA': np.int64(124), 'IND151505AAA': np.int64(125), 'IND151506AAA': np.int64(126), 'IND152024AAA': np.int64(127), 'IND152026AAA': np.int64(128), 'IND152101AAA': np.int64(129), 'IND152107AAA': np.int64(130), 'IND152116AAA': np.int64(131), 'IND152123AAA': n ...

# %%
df.shape
# Out:
# (144316, 23)

# %%
# Separate features and target
X = df.drop(columns=['actual_time'])  # drop the target
y = df['actual_time']

# %%
# Filter train and test data based on 'data' column, then drop 'data' column
X_train = X[df['data'] == 1].drop(columns=['data'])
X_test = X[df['data'] == 0].drop(columns=['data'])
y_train = y[df['data'] == 1]
y_test = y[df['data'] == 0]

# %%
X_train.head()
# Out:
#    route_type  source_center  destination_center  start_scan_to_end_scan  \
# 0           0            492                 486                    86.0
# 1           0            492                 486                    86.0
# 2           0            492                 486                    86.0
# 3           0            492                 486                    86.0
# 4           0            492                 486                    86.0
#
#    is_cutoff  osrm_time    factor  segment_actual_time  segment_osrm_time  \
# 0          1       11.0  1.272727                 14.0               11.0
# 1          1       20.0  1.200000                 10.0                9.0
# 2          1       28.0  1.428571                 16.0                7.0
# 3          1       40.0  1.550000                 21.0               12.0
# 4          0       44.0  1.545455                  6.0                5.0
#
#    segment_factor  ...  creation_weekday  creation_month  start_hour  \
# 0        1.272727  ...                 3               9           3
# 1        1.111111  ...                 3               9           3
# 2        2.285714  ...                 3               9           3
# 3        1.750000  ...                 3               9           3
# 4        1.200000  ...                 3               9           3
#
#    start_weekday  start_month  actual_vs_osrm_time_ratio  \
# 0              3            9                   1.272612
# 1              3            9                   1.199940
# 2              3            9                   1.428520
# 3              3            9                   1.549961
# 4              3            9                   1.545419
#
#    segment_actual_vs_osrm_ratio  delivery_efficiency  \
# 0                      1.272612             0.127905
# 1                      1.110988             0.232555
# 2                      2.285388             0.325578
# 3                      1.749854             0.465111
# 4                      1.199760             0.511622
#
#    avg_segment_actual_time_by_route  avg_segment_osrm_time_by_route
# 0                         24.507724                       10.550283
# 1                         24.507724                       10.550283
# 2                         24.507724                       10.550283
# 3                         24.507724                       10.550283
# 4                         24.507724                       10.550283
#
# [5 rows x 21 columns]

# %%
# Normalize the data (important for neural networks)
scaler = StandardScaler()
# Select only numerical columns
X_train_num = X_train.select_dtypes(include=['int64', 'float64'])
X_test_num = X_test.select_dtypes(include=['int64', 'float64'])

# %%
# Apply scaling only on numerical columns
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_num)
X_test_scaled = scaler.transform(X_test_num)

# %%
# Step 1: Define candidate alpha values
alphas = [0.01, 0.1, 1.0, 10.0, 100.0]

# %%
# Step 3: Fit RidgeCV
ridge_cv = RidgeCV(alphas=alphas, scoring='neg_mean_squared_error', cv=5)
ridge_cv.fit(X_train_scaled, y_train)
# Out:
# RidgeCV(alphas=[0.01, 0.1, 1.0, 10.0, 100.0], cv=5,
#         scoring='neg_mean_squared_error')

# %%
# Step 4: Get the best alpha
print("Best alpha:", ridge_cv.alpha_)
# Out:
# Best alpha: 0.01

# %%
# Step 5: Evaluate performance on test data
y_pred = ridge_cv.predict(X_test_scaled)
mse = mean_squared_error(y_test, y_pred)

print("Test MSE:", mse)
print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
# Out:
# Test MSE: 11767.591074739279
# MAE: 52.80
# RMSE: 108.48

# %%
# Compare predictions
comparison_df = pd.DataFrame({
    'Actual': y_test.values,
    'Predicted': y_pred
})
comparison_df['Error'] = abs(comparison_df['Actual'] - comparison_df['Predicted'])
print(comparison_df.head())
# Out:
#    Actual  Predicted      Error
# 0    20.0 -34.029403  54.029403
# 1    40.0   8.942454  31.057546
# 2    51.0  21.077114  29.922886
# 3    41.0  -0.849718  41.849718
# 4    61.0  44.315332  16.684668

# %%
comparison_df['Relative_Error'] = abs(comparison_df['Predicted'] - comparison_df['Actual']) / comparison_df['Actual']
comparison_df['Correct'] = comparison_df['Relative_Error'] <= 0.30

accuracy = comparison_df['Correct'].mean() * 100
print(f"Relative Accuracy (±20% of actual): {accuracy:.2f}%")
# Out:
# Relative Accuracy (±20% of actual): 74.24%

# %%
# Mark as "Correct" if prediction is within ±20 units of actual value
threshold = 20  # You can change this
comparison_df['Correct'] = comparison_df['Error'] <= threshold

# Count how many are correct vs incorrect
print(comparison_df['Correct'].value_counts())
# Out:
# Correct
# False    21077
# True     18607
# Name: count, dtype: int64
